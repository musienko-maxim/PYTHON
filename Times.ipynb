# %%
import statistics
FN = "Darius-13-100m-Fly.txt"
FOLDER = "swimdata/"
with open(FOLDER + FN) as file:
 lines = file.readlines()
 times = lines[0].strip().split(",")
converts = []
for t in times:
 minutes, rest = t.split(":")
 seconds, hundredts = rest.split(".")
 converted_time = int(minutes)*60*100 + (int(seconds)*100) + int(hundredts)
 converts.append(converted_time)


average = statistics.mean(converts)
min_secs, hundredths=str(round(average/100,2)).split(".")
min_secs = int(min_secs)
minutes = min_secs//60
seconds = min_secs - minutes*60
average=str(minutes) + ":" + str(seconds) + "."+ hundredths
print(average)
# Out:
# 1:26.58
